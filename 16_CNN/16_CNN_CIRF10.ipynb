# %%
import pandas as pd
import seaborn as sn
import numpy as np 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %%
from tensorflow.keras import layers,datasets,models

# %%
(X_train,y_train),(X_test,y_test)=datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# 170508288/170498071 [==============================] - 6s 0us/step

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
X_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
get_image(X_train,y_train,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-0230e356ae02> in <module>()
# ----> 1 get_image(X_train,y_train,0)
#
# NameError: name 'get_image' is not defined

# %%
y_test[:5]
# Out:
# array([[3],
#        [8],
#        [8],
#        [0],
#        [6]], dtype=uint8)

# %%
classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]
y_train.shape
# Out:
# (50000, 1)

# %%
y_test[:5]
# Out:
# array([[3],
#        [8],
#        [8],
#        [0],
#        [6]], dtype=uint8)

# %%
y_train=y_train.reshape(-1)
y_test=y_test.reshape(-1)

# %%
def get_image(X,y,index):
  plt.figure(figsize=(5,2))
  plt.imshow(X[index])
  plt.xlabel(classes[y[index]])

# %%
get_image(X_train,y_train,1)

# %%
X_train=X_train/255
X_test=X_test/255

# %%
model=models.Sequential([
                         layers.Flatten(input_shape=(32,32,3)),
                         layers.Dense(3000,activation='relu'),
                         layers.Dense(100,activation='relu'),
                         layers.Dense(10,activation='softmax')
])
model.compile(
    optimizer='SGD',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1563/1563 [==============================] - 78s 50ms/step - loss: 1.8378 - accuracy: 0.3419
# Epoch 2/5
# 1563/1563 [==============================] - 76s 49ms/step - loss: 1.6475 - accuracy: 0.4156
# Epoch 3/5
# 1563/1563 [==============================] - 74s 48ms/step - loss: 1.5628 - accuracy: 0.4486
# Epoch 4/5
# 1563/1563 [==============================] - 74s 47ms/step - loss: 1.5014 - accuracy: 0.4689
# Epoch 5/5
# 1563/1563 [==============================] - 74s 48ms/step - loss: 1.4535 - accuracy: 0.4873

# %%
model.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 1.4901 - accuracy: 0.4718
# [1.4900808334350586, 0.4717999994754791]

# %%
from sklearn.metrics import confusion_matrix,classification_report
y_predict=model.predict(X_)
